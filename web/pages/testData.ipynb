# %%
import pandas as pd 
import numpy as np 
import math as math
import joblib
from joblib import dump
import os
import time

# %%
joblib.load("../utils/model/ndcg/Jaccard/5_10_1_ndcg.joblib")
# Out:
#              NDCG@1    NDCG@2    NDCG@3    NDCG@4    NDCG@5    NDCG@6  \
# User-1     0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# User-2     0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# User-3     0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# User-4     0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# User-5     0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# ...             ...       ...       ...       ...       ...       ...
# User-456   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# User-457   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# User-458   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# User-459   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# Rata-rata  0.021786  0.017572  0.017539  0.016788  0.016872  0.016697
#
#              NDCG@7    NDCG@8    NDCG@9   NDCG@10   NDCG@11   NDCG@12  \
# ...

# %%
import joblib

# Load NDCG dataframe
ndcg_df = joblib.load("../utils/model/ndcg/RJ/5_10_1_ndcg.joblib")

# Hapus baris 'Rata-rata' kalau ada
ndcg_df = ndcg_df[~ndcg_df.index.str.contains("Rata-rata")]

# Filter hanya NDCG@1
ndcg_at_1 = ndcg_df["NDCG@5"]

# Ambil user yang NDCG@1 > 0
users_with_ndcg1 = ndcg_at_1[ndcg_at_1 > 0]

# Tampilkan hasil
print("📈 Jumlah user dengan NDCG@1 > 0:", len(users_with_ndcg1))
print("👤 Daftar user dengan NDCG@1 > 0:")
print(users_with_ndcg1)
# Out:
# 📈 Jumlah user dengan NDCG@1 > 0: 64
# 👤 Daftar user dengan NDCG@1 > 0:
# User-1      0.146068
# User-7      0.553146
# User-8      0.146068
# User-13     0.339160
# User-34     0.146068
#               ...
# User-374    0.339160
# User-387    0.169580
# User-393    0.339160
# User-397    0.339160
# User-402    0.339160
# Name: NDCG@5, Length: 64, dtype: float64

# %%
import joblib

# Load NDCG dataframe
ndcg_df = joblib.load("../utils/model/ndcg/Jaccard/5_10_1_ndcg.joblib")

# Hapus baris 'Rata-rata' kalau ada
ndcg_df = ndcg_df[~ndcg_df.index.str.contains("Rata-rata")]

# Filter hanya NDCG@1
ndcg_at_1 = ndcg_df["NDCG@5"]

# Ambil user yang NDCG@1 > 0
users_with_ndcg1 = ndcg_at_1[ndcg_at_1 > 0]

# Tampilkan hasil
print("📈 Jumlah user dengan NDCG@1 > 0:", len(users_with_ndcg1))
print("👤 Daftar user dengan NDCG@1 > 0:")
print(users_with_ndcg1)
# Out:
# 📈 Jumlah user dengan NDCG@1 > 0: 34
# 👤 Daftar user dengan NDCG@1 > 0:
# User-13     0.213986
# User-36     0.169580
# User-43     0.169580
# User-57     0.169580
# User-69     0.131205
# User-83     0.146068
# User-86     0.339160
# User-94     0.146068
# User-110    0.169580
# User-125    0.169580
# User-126    0.213986
# User-140    0.339160
# User-149    0.339160
# User-155    0.169580
# User-158    0.131205
# User-195    0.146068
# User-203    0.131205
# User-220    0.339160
# User-243    0.213986
# User-246    0.169580
# User-260    0.131205
# User-268    0.616434
# User-273    0.339160
# User-286    0.339160
# User-291    0.339160
# User-293    0.213986
# User-304    0.146068
# User-306    0.339160
# User-346    0.277273
# User-385    0.213986
# User-387    0.131205
# User-393    0.169580
# User-399    0.131205
# User-427    0.339160
# Name: NDCG@5, dtype: float64

# %%
joblib.load("../utils/model/prediksi/Jaccard/5.joblib")
# Out:
#          1         2         3         4         5         6         7     \
# 1    5.000000  3.000000  4.000000  3.000000  3.000000  3.218691  4.000000
# 2    4.000000  3.222722  2.963838  3.247616  3.891988  4.830095  3.889122
# 3    3.814737  1.785034  2.182020  3.027970  3.085057  2.371788  3.193913
# 4    5.046868  3.067127  4.001402  3.844595  3.888865  4.428490  4.923513
# 5    3.750135  2.815731  2.322002  2.763512  3.070289  2.139646  3.667401
# ..        ...       ...       ...       ...       ...       ...       ...
# 939  4.776029  3.958011  4.049760  3.642780  4.181584  5.034501  3.625027
# 940  3.403160  3.252267  2.487956  2.000000  2.443996  2.845468  4.000000
# 941  5.000000  3.576549  3.975729  2.953050  3.741924  4.123861  4.000000
# 942  4.878181  3.814061  3.478054  4.069125  4.053574  4.071380  4.239001
# 943  3.972798  5.000000  4.285180  2.845941  3.427859  3.211306  4.236277
#
#          8         9         10    ...      1673      1674      1675  \
# ...

# %%
joblib.load("../utils/model/topN/Jaccard/5_10_1.joblib")
# Out:
# [[1466,
#   1598,
#   895,
#   921,
#   1652,
#   1641,
#   1367,
#   1366,
#   1292,
#   1499,
#   1448,
#   1020,
#   312,
#   653,
#   745,
#   1644,
#   1649,
#   1635,
#   912,
#   1650],
#  [850,
#   1466,
#   1598,
#   1448,
#   1641,
#   1652,
#   1292,
#   131,
#   1499,
#   653,
#   319,
#   407,
#   659,
#   518,
#   317,
#   49,
#   1193,
#   510,
#   1649,
#   1650],
#  [1466,
#   1598,
#   18,
#   850,
#   173,
#   1652,
#   749,
#   1641,
#   1448,
#   922,
#   99,
#   1499,
#   21,
#   1292,
#   305,
#   55,
#   284,
#   22,
#   912,
#   1635],
#  [1366,
#   1466,
#   319,
#   49,
#   1598,
#   143,
#   922,
#   1652,
#   21,
#   612,
#   1448,
#   1292,
#   1499,
#   1661,
#   301,
#   898,
#   284,
#   1343,
#   512,
#   602],
#  [1366,
#   1466,
#   1598,
#   1641,
#   1652,
#   206,
#   197,
#   1232,
#   530,
#   1628,
#   1367,
#   1499,
#   1661,
#   1448,
#   317,
#   651,
#   245,
#   895,
#   11,
#   1079],
#  [1466,
#   1598,
#   1641,
#   1448,
#   1367,
# ...
